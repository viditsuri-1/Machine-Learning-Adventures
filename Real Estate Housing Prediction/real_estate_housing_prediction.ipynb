# %% [markdown]
# # Task6: Predicting Real Estate House Prices

# %% [markdown]
# ## This task is provided to test your understanding of building a Linear Regression model for a provided dataset

# %% [markdown]
# ### Dataset: Real_estate.csv

# %% [markdown]
# ### Import the necessary libraries
# #### Hint: Also import seaborn

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns

# %% [markdown]
# ### Read the csv data into a pandas dataframe and display the first 5 samples

# %%
estate_data = pd.read_csv(r"C:\Users\vidit\Desktop\AI Development\ML 1\Task 6\Real estate.csv")
estate_data.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %% [markdown]
# ### Show more information about the dataset

# %%
estate_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %% [markdown]
# ### Find how many samples are there and how many columns are there in the dataset

# %%
estate_data.shape
# Out:
# (414, 8)

# %% [markdown]
# ### What are the features available in the dataset?

# %%
estate_data.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %% [markdown]
# ### Check if any features have missing data

# %%
estate_data.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %% [markdown]
# ### Group all the features as dependent features in X

# %%
x = estate_data.drop('Y house price of unit area', axis=1)
x
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %% [markdown]
# ### Group feature(s) as independent features in y

# %%
y = df['Y house price of unit area']
y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %% [markdown]
# ### Split the dataset into train and test data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

# %% [markdown]
# ### Choose the model (Linear Regression)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Create an Estimator object

# %%
model = LinearRegression()

# %% [markdown]
# ### Train the model

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Apply the model

# %%
y_test_pred = model.predict(x_test)
y_test_pred
# Out:
# array([49.44820435, 15.50025528, 34.30178044, 42.28092076, 38.16985893,
#        36.93208211, 14.10439843, 39.37618628, 46.60903387, 34.46559225,
#        50.51573362, 39.28410123, 54.76199538, 45.41974015, 34.31901493,
#        28.11638984, 42.5300086 , 47.18505538, 43.25912022, 34.37905991,
#        40.48460989, 45.21159722, 41.87865425, 38.53403868, 32.6473287 ,
#        45.89943341, 30.99553046, 35.61580456, 33.42216169, 39.81450175,
#        44.16666053, 47.76360961, 45.17110685, 41.95708275, 41.84186238,
#        51.46190213, 41.23185704, 42.47229463, 44.24217562, 34.08187625,
#        41.32675361, 53.14195582])

# %% [markdown]
# ### Display the coefficients

# %%
c = model.coef_
c
# Out:
# array([-2.63445554e-03,  4.91917072e+00, -2.62730993e-01, -4.58736107e-03,
#         1.10618685e+00,  2.32407760e+02, -3.79383074e+01])

# %% [markdown]
# ### Find how well the trained model did with testing data

# %%
score = r2_score(y_test, y_test_pred)
score
# Out:
# 0.6682078737908628

# %% [markdown]
# ### Plot House Age Vs Price
# #### Hint: Use regplot in sns

# %%
sns.regplot(x="X2 house age", y="Y house price of unit area", data=estate_data)
# Out:
# <Axes: xlabel='X2 house age', ylabel='Y house price of unit area'>

# %% [markdown]
# ### Plot Distance to MRT station Vs Price

# %%
sns.regplot(x="X3 distance to the nearest MRT station", y="Y house price of unit area", data=estate_data)
# Out:
# <Axes: xlabel='X3 distance to the nearest MRT station', ylabel='Y house price of unit area'>

# %% [markdown]
# ### Plot Number of Convienience Stores Vs Price

# %%
sns.regplot(x="X4 number of convenience stores", y="Y house price of unit area", data=estate_data)
# Out:
# <Axes: xlabel='X4 number of convenience stores', ylabel='Y house price of unit area'>
